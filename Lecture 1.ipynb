# %% [markdown]
# # PIE CHART CATERGORICAL DATA

# %%
population <- c(4805,	5932,	17154,	22215,	28504)
lbls <- c("Age 0-14 years","Age 15-24 years","Age 25-44 years","Age 45-64 years","Age 65+ years")
pie(population, labels = lbls, main="Age Groups in Dublin City")
# Out:
# Plot with title "Age Groups in Dublin City"

# %% [markdown]
# # Simple Bar Plot
# # Film feedback

# %%
FilmFeedback <- c(4,	1,	4)

counts <- table(mtcars$gear)
barplot(FilmFeedback, main="Did you like Pixels?", 
        xlab="Statement", names.arg=c("Hated it","ok","loved it"))
# Out:
# Plot with title "Did you like Pixels?"

# %%
# Simple Scatterplot
# READING IN DATA

# %%
PearsonLee<-read.csv("PearsonLeeSimple.csv")

plot(PearsonLee$child, PearsonLee$parent, main="Scatterplot Example", 
     xlab="Child ", ylab="Parent ", pch=19)
# Out:
# Plot with title "Scatterplot Example"
